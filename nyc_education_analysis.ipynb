# %%
import pandas as pd

df = pd.read_csv('data/2017-2018_Graduation_Outcomes.csv')
df.info()

# %%
df.describe(include='all')

# %%
df.columns

# %%
clean_df = df[
    ['Demographic Category',
     'Demographic Variable',
     'Cohort Year',
     'Total Cohort #',
     'Total Grads #',
     'Total Grads % of cohort']
]
clean_df = clean_df.rename(columns={
    'Demographic Category': 'demographic_category',
    'Demographic Variable': 'demographic_variable',
    'Cohort Year': 'cohort_year',
    'Total Cohort #': 'total_cohort_number',
    'Total Grads #': 'total_graduates_number',
    'Total Grads % of cohort': 'total_graduates_percentage'
})

# %%
clean_df = clean_df.dropna()
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650 entries, 0 to 1649
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   demographic_category        1650 non-null   object
#  1   demographic_variable        1650 non-null   object
#  2   cohort_year                 1650 non-null   object
#  3   total_cohort_number         1650 non-null   object
#  4   total_graduates_number      1650 non-null   object
#  5   total_graduates_percentage  1650 non-null   object
# dtypes: object(6)
# memory usage: 77.5+ KB
